# %%
# !pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.5.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (4.66.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2023.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.9.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch_geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch_geometric) (3.4.0)
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.5.2

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as graphnn
from sklearn.metrics import f1_score
from torch_geometric.loader import DataLoader
from torch_geometric.utils import scatter
from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import KFold
from itertools import product

# %%
from torch_geometric.datasets import TUDataset

dataset_en = TUDataset(root='', name='ENZYMES',use_node_attr = True)
dataset_rd = TUDataset(root='', name='REDDIT-BINARY')
dataset_pr = TUDataset(root='', name='PROTEINS')
# Out:
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/ENZYMES.zip
# Processing...
# Done!
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/REDDIT-BINARY.zip
# Processing...
# Done!
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/PROTEINS.zip
# Processing...
# Done!

# %%
print(len(dataset_en))
print(len(dataset_rd))
print(len(dataset_pr))

print(dataset_en.num_classes)
print(dataset_rd.num_classes)
print(dataset_pr.num_classes)

print(dataset_en.num_node_features)
print(dataset_rd.num_node_features)
print(dataset_pr.num_node_features)
# Out:
# 600
# 2000
# 1113
# 6
# 2
# 2
# 21
# 0
# 3

# %%
from torch_geometric.loader import DataLoader
train_en = dataset_en[:int(len(dataset_en)*0.8)]
val_en = dataset_en[int(len(dataset_en)*0.8):int(len(dataset_en)*0.9)]
test_en = dataset_en[int(len(dataset_en)*0.9):]

train_en_loader = DataLoader(train_en, batch_size=32, shuffle=True)
val_en_loader = DataLoader(val_en, batch_size=32, shuffle=False)
test_en_loader = DataLoader(test_en, batch_size=32, shuffle=False)

# %%
class MLP1(torch.nn.Module):

    def __init__(self, input_size, hidden_size, output_size):
        super(MLP1, self).__init__()
        self.fc_global = nn.Linear(input_size, hidden_size)
        self.fc = nn.Linear(hidden_size, output_size)
        self.relu = nn.ReLU()

    def forward(self, data):
      x = self.fc_global(data.x)
      x = self.relu(x)
      x = self.fc(x)
      x = graphnn.global_mean_pool(x, data.batch)
      return x

# %%
class MLP1(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP1, self).__init__()

        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)

    def forward(self, data):
        x = self.fc1(data.x)
        x = graphnn.global_add_pool(x, data.batch)
        x = self.fc2(x)
        return x

# %%
def train(model, loss_fcn, device, optimizer, max_epochs, train_dataloader, val_dataloader, patience=30):
    best_val_score = 0
    patience_counter = 0
    metrics_history = {'train_loss': [], 'val_loss': [], 'f1_micro': [], 'f1_macro': [], 'accuracy': [], 'best_score':[]}

    for epoch in range(max_epochs):
        model.train()
        train_losses = []
        for batch in train_dataloader:
            if batch.x is None:
                raise ValueError("Node features are missing. Ensure data.x is correctly set.")
            batch = batch.to(device)
            optimizer.zero_grad()
            logits = model(batch)
            loss = loss_fcn(logits, batch.y)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        val_loss = evaluate_loss(model, loss_fcn, device, val_dataloader)
        f1_micro, f1_macro, accuracy = evaluate_metrics(model, device, val_dataloader)

        # Save metrics
        metrics_history['train_loss'].append(np.mean(train_losses))
        metrics_history['val_loss'].append(val_loss)
        metrics_history['f1_micro'].append(f1_micro)
        metrics_history['f1_macro'].append(f1_macro)
        metrics_history['accuracy'].append(accuracy)

        print(f"Epoch {epoch+1}, Train Loss: {np.mean(train_losses):.4f}, Val Loss: {val_loss:.4f}, F1 Micro: {f1_micro:.4f}, F1 Macro: {f1_macro:.4f}, Accuracy: {accuracy:.4f}")

        # Early stopping logic using f1_micro score
        if f1_micro > best_val_score:
            best_val_score = f1_micro
            metrics_history['best_score'] = best_val_score
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered")
                break

    return metrics_history

# %%
def evaluate_loss(model, loss_fcn, device, dataloader):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            outputs = model(batch)
            loss = loss_fcn(outputs, batch.y)
            total_loss += loss.item()
    return total_loss / len(dataloader)

# %%
def evaluate_metrics(model, device, dataloader):
    model.eval()
    total_preds = []
    total_targets = []

    with torch.no_grad():
        for batch in dataloader:
            batch = batch.to(device)
            outputs = model(batch)
            _, predicted = torch.max(outputs, 1)
            total_preds.extend(predicted.view(-1).cpu().numpy())
            total_targets.extend(batch.y.view(-1).cpu().numpy())

    f1_micro = f1_score(total_targets, total_preds, average='micro')
    f1_macro = f1_score(total_targets, total_preds, average='macro')
    accuracy = accuracy_score(total_targets, total_preds)
    return f1_micro, f1_macro, accuracy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("\nDevice: ", device)

### Max number of epochs
max_epochs = 500
n_features = dataset_en.num_node_features
n_classes = dataset_en.num_classes
# Out:
# Device:  cuda

# %%
baseline = MLP1(
    input_size=n_features, hidden_size=256, output_size=n_classes
).to(device)

### DEFINE LOSS FUNCTION
loss_fcn = nn.CrossEntropyLoss()
### DEFINE OPTIMIZER
optimizer = torch.optim.Adam(baseline.parameters(), lr=0.005)

### TRAIN THE MODEL
metrics_history=train(
    baseline,
    loss_fcn,
    device,
    optimizer,
    max_epochs,
    train_en_loader,
    val_en_loader,
)
# Out:
# Epoch 1, Train Loss: 222.7368, Val Loss: 956.3276, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 2, Train Loss: 97.3466, Val Loss: 833.8297, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 3, Train Loss: 56.3178, Val Loss: 782.7109, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 4, Train Loss: 58.0872, Val Loss: 847.0623, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 5, Train Loss: 54.6008, Val Loss: 755.0434, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 6, Train Loss: 23.8182, Val Loss: 677.7715, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 7, Train Loss: 33.5637, Val Loss: 657.1805, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 8, Train Loss: 39.5702, Val Loss: 639.0893, F1 Micro: 0.1500, F1 Macro: 0.1364, Accuracy: 0.1500
# Epoch 9, Train Loss: 27.9771, Val Loss: 581.0397, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 10, Train Loss: 15.2881, Val Loss: 552.8737, F1 Micro: 0.1000, F1 Macro: 0.0923, Accuracy: 0.1000
# Epoch 11, Train Loss: 18.0720, Val Loss: 581.8611, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 12, Train Loss: 24.5558, Val Loss: 540.6567, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 13, Train Loss: 19.6676, Val Loss: 495.1346, F1 Micro: 0.0667, F1 Macro: 0.0615, Accuracy: 0.0667
# Epoch 14, Train Loss: 17.1004, Val Loss: 496.7846, F1 Micro: 0.3000, F1 Macro: 0.1169, Accuracy: 0.3000
# Epoch 15, Train Loss: 14.8639, Val Loss: 467.2037, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 16, Train Loss: 12.5241, Val Loss: 461.6641, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 17, Train Loss: 11.2832, Val Loss: 442.6768, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 18, Train Loss: 10.4874, Val Loss: 433.6441, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 19, Train Loss: 13.4123, Val Loss: 421.3462, F1 Micro: 0.1833, F1 Macro: 0.2222, Accuracy: 0.1833
# Epoch 20, Train Loss: 14.8784, Val Loss: 412.8246, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 21, Train Loss: 10.6793, Val Loss: 390.7954, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 22, Train Loss: 11.7487, Val Loss: 388.5843, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 23, Train Loss: 20.0180, Val Loss: 406.8352, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 24, Train Loss: 14.5351, Val Loss: 339.5113, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 25, Train Loss: 9.1047, Val Loss: 331.5635, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 26, Train Loss: 10.5124, Val Loss: 324.1704, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 27, Train Loss: 5.8399, Val Loss: 304.4910, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 28, Train Loss: 5.4262, Val Loss: 296.9874, F1 Micro: 0.0500, F1 Macro: 0.0522, Accuracy: 0.0500
# Epoch 29, Train Loss: 5.6756, Val Loss: 284.7333, F1 Micro: 0.2667, F1 Macro: 0.1702, Accuracy: 0.2667
# Epoch 30, Train Loss: 7.6618, Val Loss: 293.9548, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 31, Train Loss: 8.6102, Val Loss: 287.5772, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 32, Train Loss: 7.0024, Val Loss: 279.2270, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 33, Train Loss: 9.4472, Val Loss: 279.8362, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 34, Train Loss: 12.0128, Val Loss: 242.6815, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 35, Train Loss: 8.3096, Val Loss: 243.9947, F1 Micro: 0.0167, F1 Macro: 0.0182, Accuracy: 0.0167
# Epoch 36, Train Loss: 6.7197, Val Loss: 233.3485, F1 Micro: 0.2167, F1 Macro: 0.1083, Accuracy: 0.2167
# Epoch 37, Train Loss: 6.5793, Val Loss: 224.1694, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 38, Train Loss: 6.2121, Val Loss: 219.8386, F1 Micro: 0.1667, F1 Macro: 0.1290, Accuracy: 0.1667
# Epoch 39, Train Loss: 8.5853, Val Loss: 214.8379, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 40, Train Loss: 10.0289, Val Loss: 205.3139, F1 Micro: 0.2500, F1 Macro: 0.1395, Accuracy: 0.2500
# Epoch 41, Train Loss: 9.4571, Val Loss: 203.7851, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Epoch 42, Train Loss: 6.8766, Val Loss: 190.1399, F1 Micro: 0.0667, F1 Macro: 0.0593, Accuracy: 0.0667
# Epoch 43, Train Loss: 6.5307, Val Loss: 169.9431, F1 Micro: 0.2000, F1 Macro: 0.1500, Accuracy: 0.2000
# Epoch 44, Train Loss: 4.5588, Val Loss: 163.0050, F1 Micro: 0.0000, F1 Macro: 0.0000, Accuracy: 0.0000
# Early stopping triggered

# %%
def plot_metrics(metrics_history):
    epochs = range(1, len(metrics_history['train_loss']) + 1)

    plt.figure(figsize=(14, 10))

    plt.subplot(2, 2, 1)
    plt.plot(epochs, metrics_history['train_loss'], label='Train Loss')
    plt.plot(epochs, metrics_history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(epochs, metrics_history['f1_micro'], label='F1 Score (Micro)')
    plt.plot(epochs, metrics_history['f1_macro'], label='F1 Score (Macro)')
    plt.title('F1 Scores')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    plt.subplot(2, 2, 3)
    plt.plot(epochs, metrics_history['accuracy'], label='Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
from sklearn.model_selection import KFold
from itertools import product

# Outer k-fold cross-validation setup
outer_k_folds = 2
inner_k_folds = 2
num_epochs = 500

# Possible hyperparameters to tune
learning_rates = [0.01, 0.001]
batch_sizes = [8, 16]
patiences = [500]

# Set list to store the evaluation metrics
f1_micro_test_list = []
f1_macro_test_list = []
accuracy_test_list = []

# Prepare the outer k-fold cross-validation
outer_kf = KFold(n_splits=outer_k_folds, shuffle=True, random_state=42)

# Loop over each fold for the outer k-fold
for fold, (train_val_idx, test_idx) in enumerate(outer_kf.split(dataset_en)):
    print(f"Outer FOLD {fold}")
    print("--------------------------------")

    # Split dataset into train_val and test for the current outer fold
    train_val_dataset = dataset_en[train_val_idx]
    test_dataset = dataset_en[test_idx]

    # Initialize the best hyperparameter set and its performance score
    best_hyperparams = None
    best_score = 0

    # Inner k-fold cross-validation for hyperparameter tuning
    inner_kf = KFold(n_splits=inner_k_folds, shuffle=True, random_state=42)

    # Create all combinations of hyperparameters
    all_params = list(product(learning_rates, batch_sizes, patiences))

    # Loop over all combinations of hyperparameters
    for params in all_params:
        lr, batch_size, patience = params
        inner_scores = []

        # Perform inner k-fold cross-validation
        for inner_fold, (inner_train_idx, inner_val_idx) in enumerate(inner_kf.split(train_val_dataset)):
            print(f"Inner FOLD {inner_fold}")
            print(f"Hyperparameters: LR={lr}, Batch Size={batch_size}, Patience={patience}")

            # Split dataset into inner train and validation sets
            inner_train_dataset = train_val_dataset[inner_train_idx]
            inner_val_dataset = train_val_dataset[inner_val_idx]

            # Define train and validation dataloaders for the current inner fold
            inner_train_loader = DataLoader(inner_train_dataset, batch_size=batch_size, shuffle=True)
            inner_val_loader = DataLoader(inner_val_dataset, batch_size=batch_size, shuffle=False)

            # Initialize model and optimizer for the current inner fold
            model = MLP1(
                input_size=dataset_en.num_node_features,
                hidden_size=256,
                output_size=dataset_en.num_classes
            ).to(device)

            optimizer = torch.optim.Adam(model.parameters(), lr=lr)
            loss_fcn = torch.nn.CrossEntropyLoss()

            # Train the model for the current inner fold
            inner_metrics = train(model, loss_fcn, device, optimizer, num_epochs, inner_train_loader, inner_val_loader, patience)

            # Evaluate model performance, e.g., using validation F1 score
            # Save the model performance score for the current hyperparameter combination
            inner_scores.append(inner_metrics['best_score'])

        # Calculate the average performance over all inner folds for the current hyperparameter set
        average_score = np.mean(inner_scores)
        print(f"Average Score for hyperparameters {params}: {average_score}")

        # If the current hyperparameters outperform the previous ones, update the best_hyperparams
        if average_score > best_score:
            best_hyperparams = params
            best_score = average_score

    print(f"Best hyperparameters for Outer FOLD {fold}: {best_hyperparams} with score {best_score}")

    # Now retrain the model on the full train_val_dataset with the best_hyperparams

    # Extract best hyperparameters
    best_lr, best_batch_size, best_patience = best_hyperparams

    # DataLoader for the combined training and validation set
    train_val_loader = DataLoader(train_val_dataset, batch_size=best_batch_size, shuffle=True)

    # DataLoader for the test set
    test_loader = DataLoader(test_dataset, batch_size=best_batch_size, shuffle=False)

    # Initialize the model with the best hyperparameters
    model = MLP1(
        input_size=dataset_en.num_node_features,
        hidden_size=256,
        output_size=dataset_en.num_classes
    ).to(device)

    # Initialize the optimizer with the best learning rate
    optimizer = torch.optim.Adam(model.parameters(), lr=best_lr)

    # Loss function
    loss_fcn = torch.nn.CrossEntropyLoss()

    # Retrain the model on the full train_val_dataset
    retrained_metrics = train(
        model,
        loss_fcn,
        device,
        optimizer,
        num_epochs,
        train_val_loader,
        test_loader,  # We're using the test_loader here to monitor the performance, but we do not use this for making decisions
        best_patience
    )

    # After retraining, evaluate on the test set
    f1_micro_test, f1_macro_test, accuracy_test = evaluate_metrics(model, device, test_loader)
    print(f"Test set evaluation - F1 Micro: {f1_micro_test:.4f}, F1 Macro: {f1_macro_test:.4f}, Accuracy: {accuracy_test:.4f}")
    f1_micro_test_list.append(f1_micro_test)
    f1_macro_test_list.append(f1_macro_test)
    accuracy_test_list.append(accuracy_test)
    # Optionally, save your retrained model
    torch.save(model.state_dict(), f'Basic_model_fold_{fold}.pth')
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 26, Train Loss: 1.5857, Val Loss: 1.7741, F1 Micro: 0.2667, F1 Macro: 0.2525, Accuracy: 0.2667
# Epoch 27, Train Loss: 1.5740, Val Loss: 1.8044, F1 Micro: 0.2600, F1 Macro: 0.2316, Accuracy: 0.2600
# Epoch 28, Train Loss: 1.5613, Val Loss: 1.8102, F1 Micro: 0.2400, F1 Macro: 0.1872, Accuracy: 0.2400
# Epoch 29, Train Loss: 1.5952, Val Loss: 1.7346, F1 Micro: 0.2533, F1 Macro: 0.2197, Accuracy: 0.2533
# Epoch 30, Train Loss: 1.5544, Val Loss: 1.7548, F1 Micro: 0.2933, F1 Macro: 0.2392, Accuracy: 0.2933
# Epoch 31, Train Loss: 1.5626, Val Loss: 1.7575, F1 Micro: 0.2667, F1 Macro: 0.2500, Accuracy: 0.2667
# Epoch 32, Train Loss: 1.5711, Val Loss: 2.0149, F1 Micro: 0.2600, F1 Macro: 0.2043, Accuracy: 0.2600
# Epoch 33, Train Loss: 1.6006, Val Loss: 1.8293, F1 Micro: 0.2433, F1 Macro: 0.2098, Accuracy: 0.2433
# Epoch 34, Train Loss: 1.5645, Val Loss: 1.8483, F1 Micro: 0.2433, F1 Macro: 0.2133, Accuracy: 0.2433
# Epoch 35, Train Loss: 1.5635, Val Loss: 1.8230, F1 Micro: 0.2800, F1 Macro: 0.2693, Accuracy: 0.2800
# Epoch 36, Train Loss: 1.5335, Val Loss: 1.8089, F1 Micro: 0.2467, F1 Macro: 0.2440, Accuracy: 0.2467
# Epoch 37, Train Loss: 1.5352, Val Loss: 1.7955, F1 Micro: 0.3067, F1 Macro: 0.3033, Accuracy: 0.3067
# Epoch 38, Train Loss: 1.5597, Val Loss: 1.7781, F1 Micro: 0.2867, F1 Macro: 0.2623, Accuracy: 0.2867
# Epoch 39, Train Loss: 1.5136, Val Loss: 1.8068, F1 Micro: 0.2867, F1 Macro: 0.2704, Accuracy: 0.2867
# Epoch 40, Train Loss: 1.5245, Val Loss: 1.8004, F1 Micro: 0.2833, F1 Macro: 0.2544, Accuracy: 0.2833
# Epoch 41, Train Loss: 1.5137, Val Loss: 1.8316, F1 Micro: 0.2533, F1 Macro: 0.2158, Accuracy: 0.2533
# Epoch 42, Train Loss: 1.5066, Val Loss: 1.8438, F1 Micro: 0.3200, F1 Macro: 0.2970, Accuracy: 0.3200
# Epoch 43, Train Loss: 1.5018, Val Loss: 1.7884, F1 Micro: 0.3033, F1 Macro: 0.2895, Accuracy: 0.3033
# Epoch 44, Train Loss: 1.4745, Val Loss: 1.8950, F1 Micro: 0.2567, F1 Macro: 0.2397, Accuracy: 0.2567
# Epoch 45, Train Loss: 1.4861, Val Loss: 1.7817, F1 Micro: 0.3233, F1 Macro: 0.2938, Accuracy: 0.3233
# Epoch 46, Train Loss: 1.5157, Val Loss: 1.8076, F1 Micro: 0.2567, F1 Macro: 0.2293, Accuracy: 0.2567
# Epoch 47, Train Loss: 1.4864, Val Loss: 1.8146, F1 Micro: 0.2967, F1 Macro: 0.2869, Accuracy: 0.2967
# Epoch 48, Train Loss: 1.4700, Val Loss: 1.7949, F1 Micro: 0.2933, F1 Macro: 0.2818, Accuracy: 0.2933
# Epoch 49, Train Loss: 1.4648, Val Loss: 1.8910, F1 Micro: 0.2933, F1 Macro: 0.2780, Accuracy: 0.2933
# Epoch 50, Train Loss: 1.4804, Val Loss: 1.7670, F1 Micro: 0.2933, F1 Macro: 0.2787, Accuracy: 0.2933
# Epoch 51, Train Loss: 1.4433, Val Loss: 1.9252, F1 Micro: 0.2733, F1 Macro: 0.2240, Accuracy: 0.2733
# Epoch 52, Train Loss: 1.4559, Val Loss: 1.8189, F1 Micro: 0.2767, F1 Macro: 0.2532, Accuracy: 0.2767
# Epoch 53, Train Loss: 1.4834, Val Loss: 1.8940, F1 Micro: 0.2967, F1 Macro: 0.2814, Accuracy: 0.2967
# Epoch 54, Train Loss: 1.4444, Val Loss: 1.7729, F1 Micro: 0.3067, F1 Macro: 0.2914, Accuracy: 0.3067
# Epoch 55, Train Loss: 1.4144, Val Loss: 1.8204, F1 Micro: 0.2700, F1 Macro: 0.2414, Accuracy: 0.2700
# Epoch 56, Train Loss: 1.4396, Val Loss: 1.8628, F1 Micro: 0.3067, F1 Macro: 0.2934, Accuracy: 0.3067
# Epoch 57, Train Loss: 1.4290, Val Loss: 1.8873, F1 Micro: 0.2800, F1 Macro: 0.2775, Accuracy: 0.2800
# Epoch 58, Train Loss: 1.4420, Val Loss: 1.9778, F1 Micro: 0.2933, F1 Macro: 0.2619, Accuracy: 0.2933
# Epoch 59, Train Loss: 1.4299, Val Loss: 1.9285, F1 Micro: 0.3433, F1 Macro: 0.3145, Accuracy: 0.3433
# Epoch 60, Train Loss: 1.4031, Val Loss: 1.8600, F1 Micro: 0.3300, F1 Macro: 0.3161, Accuracy: 0.3300
# Epoch 61, Train Loss: 1.3862, Val Loss: 1.8892, F1 Micro: 0.3567, F1 Macro: 0.3183, Accuracy: 0.3567
# Epoch 62, Train Loss: 1.4007, Val Loss: 1.9793, F1 Micro: 0.3000, F1 Macro: 0.2891, Accuracy: 0.3000
# Epoch 63, Train Loss: 1.4039, Val Loss: 1.9106, F1 Micro: 0.3433, F1 Macro: 0.3153, Accuracy: 0.3433
# Epoch 64, Train Loss: 1.3891, Val Loss: 1.8692, F1 Micro: 0.3300, F1 Macro: 0.3133, Accuracy: 0.3300
# Epoch 65, Train Loss: 1.3958, Val Loss: 1.9095, F1 Micro: 0.3367, F1 Macro: 0.3251, Accuracy: 0.3367
# Epoch 372, Train Loss: 0.7102, Val Loss: 1.8471, F1 Micro: 0.5200, F1 Macro: 0.5047, Accuracy: 0.5200
# Epoch 373, Train Loss: 0.7167, Val Loss: 1.8963, F1 Micro: 0.5233, F1 Macro: 0.5174, Accuracy: 0.5233
# Epoch 374, Train Loss: 0.7238, Val Loss: 1.8109, F1 Micro: 0.5233, F1 Macro: 0.5290, Accuracy: 0.5233
# Epoch 375, Train Loss: 0.7088, Val Loss: 1.8202, F1 Micro: 0.5400, F1 Macro: 0.5444, Accuracy: 0.5400
# Epoch 376, Train Loss: 0.6723, Val Loss: 1.8361, F1 Micro: 0.5567, F1 Macro: 0.5607, Accuracy: 0.5567
# Epoch 377, Train Loss: 0.6574, Val Loss: 1.9127, F1 Micro: 0.5167, F1 Macro: 0.5175, Accuracy: 0.5167
# Epoch 378, Train Loss: 0.7309, Val Loss: 1.8768, F1 Micro: 0.5300, F1 Macro: 0.5251, Accuracy: 0.5300
# Epoch 379, Train Loss: 0.6811, Val Loss: 1.8718, F1 Micro: 0.5233, F1 Macro: 0.5308, Accuracy: 0.5233
# Epoch 380, Train Loss: 0.6480, Val Loss: 1.8484, F1 Micro: 0.5267, F1 Macro: 0.5247, Accuracy: 0.5267
# Epoch 381, Train Loss: 0.6500, Val Loss: 1.8620, F1 Micro: 0.5300, F1 Macro: 0.5271, Accuracy: 0.5300
# Epoch 382, Train Loss: 0.6456, Val Loss: 1.8572, F1 Micro: 0.5233, F1 Macro: 0.5248, Accuracy: 0.5233
# Epoch 383, Train Loss: 0.6553, Val Loss: 1.8988, F1 Micro: 0.5100, F1 Macro: 0.5073, Accuracy: 0.5100
# Epoch 384, Train Loss: 0.6535, Val Loss: 1.8359, F1 Micro: 0.5300, F1 Macro: 0.5306, Accuracy: 0.5300
# Epoch 385, Train Loss: 0.6404, Val Loss: 1.8875, F1 Micro: 0.5000, F1 Macro: 0.4880, Accuracy: 0.5000
# Epoch 386, Train Loss: 0.6528, Val Loss: 1.8766, F1 Micro: 0.4833, F1 Macro: 0.4787, Accuracy: 0.4833
# Epoch 387, Train Loss: 0.6502, Val Loss: 1.8775, F1 Micro: 0.5267, F1 Macro: 0.5272, Accuracy: 0.5267
# Epoch 388, Train Loss: 0.6266, Val Loss: 1.8792, F1 Micro: 0.5433, F1 Macro: 0.5445, Accuracy: 0.5433
# Epoch 389, Train Loss: 0.6451, Val Loss: 1.8514, F1 Micro: 0.5500, F1 Macro: 0.5436, Accuracy: 0.5500
# Epoch 390, Train Loss: 0.6528, Val Loss: 1.8795, F1 Micro: 0.5333, F1 Macro: 0.5293, Accuracy: 0.5333
# Epoch 391, Train Loss: 0.6483, Val Loss: 1.8466, F1 Micro: 0.5333, F1 Macro: 0.5323, Accuracy: 0.5333
# Epoch 392, Train Loss: 0.6430, Val Loss: 1.8275, F1 Micro: 0.5433, F1 Macro: 0.5426, Accuracy: 0.5433
# Epoch 393, Train Loss: 0.6249, Val Loss: 1.8939, F1 Micro: 0.5200, F1 Macro: 0.5150, Accuracy: 0.5200
# Epoch 394, Train Loss: 0.6498, Val Loss: 1.9045, F1 Micro: 0.5367, F1 Macro: 0.5373, Accuracy: 0.5367
# Epoch 395, Train Loss: 0.6766, Val Loss: 1.8706, F1 Micro: 0.5167, F1 Macro: 0.5088, Accuracy: 0.5167
# Epoch 396, Train Loss: 0.6449, Val Loss: 1.9375, F1 Micro: 0.5067, F1 Macro: 0.4890, Accuracy: 0.5067
# Epoch 397, Train Loss: 0.6538, Val Loss: 1.9008, F1 Micro: 0.5267, F1 Macro: 0.5281, Accuracy: 0.5267
# Epoch 398, Train Loss: 0.6364, Val Loss: 1.9956, F1 Micro: 0.4500, F1 Macro: 0.4400, Accuracy: 0.4500
# Epoch 399, Train Loss: 0.6574, Val Loss: 1.9113, F1 Micro: 0.5433, F1 Macro: 0.5239, Accuracy: 0.5433
# Epoch 400, Train Loss: 0.6387, Val Loss: 1.9240, F1 Micro: 0.5267, F1 Macro: 0.5272, Accuracy: 0.5267
# Epoch 401, Train Loss: 0.6206, Val Loss: 1.8717, F1 Micro: 0.5300, F1 Macro: 0.5283, Accuracy: 0.5300
# Epoch 402, Train Loss: 0.6202, Val Loss: 1.8818, F1 Micro: 0.5300, F1 Macro: 0.5269, Accuracy: 0.5300
# Epoch 403, Train Loss: 0.6162, Val Loss: 1.8574, F1 Micro: 0.5533, F1 Macro: 0.5570, Accuracy: 0.5533
# Epoch 404, Train Loss: 0.6262, Val Loss: 1.8950, F1 Micro: 0.5500, F1 Macro: 0.5373, Accuracy: 0.5500
# Epoch 405, Train Loss: 0.5960, Val Loss: 1.8778, F1 Micro: 0.5400, F1 Macro: 0.5414, Accuracy: 0.5400
# Epoch 406, Train Loss: 0.5939, Val Loss: 1.8937, F1 Micro: 0.5500, F1 Macro: 0.5538, Accuracy: 0.5500
# Epoch 407, Train Loss: 0.6290, Val Loss: 1.9257, F1 Micro: 0.5033, F1 Macro: 0.5062, Accuracy: 0.5033
# Epoch 408, Train Loss: 0.6376, Val Loss: 1.8876, F1 Micro: 0.5300, F1 Macro: 0.5299, Accuracy: 0.5300
# Epoch 409, Train Loss: 0.6162, Val Loss: 1.8979, F1 Micro: 0.5400, F1 Macro: 0.5432, Accuracy: 0.5400
# Epoch 410, Train Loss: 0.6117, Val Loss: 1.8898, F1 Micro: 0.5467, F1 Macro: 0.5423, Accuracy: 0.5467
# Epoch 411, Train Loss: 0.6021, Val Loss: 1.8819, F1 Micro: 0.5467, F1 Macro: 0.5487, Accuracy: 0.5467
# Epoch 412, Train Loss: 0.5970, Val Loss: 1.8884, F1 Micro: 0.5567, F1 Macro: 0.5635, Accuracy: 0.5567
# Epoch 413, Train Loss: 0.6012, Val Loss: 1.9304, F1 Micro: 0.5200, F1 Macro: 0.5046, Accuracy: 0.5200
# Epoch 414, Train Loss: 0.5990, Val Loss: 1.9418, F1 Micro: 0.5400, F1 Macro: 0.5383, Accuracy: 0.5400
# Epoch 415, Train Loss: 0.5803, Val Loss: 1.9018, F1 Micro: 0.5467, F1 Macro: 0.5414, Accuracy: 0.5467
# Epoch 438, Train Loss: 0.5768, Val Loss: 2.0444, F1 Micro: 0.5200, F1 Macro: 0.5154, Accuracy: 0.5200
# Epoch 439, Train Loss: 0.6418, Val Loss: 2.1077, F1 Micro: 0.5233, F1 Macro: 0.5252, Accuracy: 0.5233
# Epoch 440, Train Loss: 0.6390, Val Loss: 1.9685, F1 Micro: 0.5400, F1 Macro: 0.5401, Accuracy: 0.5400
# Epoch 441, Train Loss: 0.6299, Val Loss: 2.0236, F1 Micro: 0.5367, F1 Macro: 0.5385, Accuracy: 0.5367
# Epoch 442, Train Loss: 0.5955, Val Loss: 1.9497, F1 Micro: 0.5467, F1 Macro: 0.5451, Accuracy: 0.5467
# Epoch 443, Train Loss: 0.5582, Val Loss: 1.9634, F1 Micro: 0.5433, F1 Macro: 0.5469, Accuracy: 0.5433
# Epoch 444, Train Loss: 0.5704, Val Loss: 2.0779, F1 Micro: 0.4867, F1 Macro: 0.4729, Accuracy: 0.4867
# Epoch 445, Train Loss: 0.5766, Val Loss: 1.9471, F1 Micro: 0.5533, F1 Macro: 0.5583, Accuracy: 0.5533
# Epoch 446, Train Loss: 0.6016, Val Loss: 1.9981, F1 Micro: 0.5400, F1 Macro: 0.5417, Accuracy: 0.5400
# Epoch 447, Train Loss: 0.5754, Val Loss: 2.0995, F1 Micro: 0.5100, F1 Macro: 0.4965, Accuracy: 0.5100
# Epoch 448, Train Loss: 0.5893, Val Loss: 2.0075, F1 Micro: 0.5300, F1 Macro: 0.5245, Accuracy: 0.5300
# Epoch 449, Train Loss: 0.5494, Val Loss: 1.9662, F1 Micro: 0.5600, F1 Macro: 0.5504, Accuracy: 0.5600
# Epoch 450, Train Loss: 0.5604, Val Loss: 2.0805, F1 Micro: 0.5267, F1 Macro: 0.5082, Accuracy: 0.5267
# Epoch 451, Train Loss: 0.5871, Val Loss: 2.0922, F1 Micro: 0.5200, F1 Macro: 0.5153, Accuracy: 0.5200
# Epoch 452, Train Loss: 0.5784, Val Loss: 1.9898, F1 Micro: 0.5400, F1 Macro: 0.5313, Accuracy: 0.5400
# Epoch 453, Train Loss: 0.5583, Val Loss: 2.0683, F1 Micro: 0.5100, F1 Macro: 0.5005, Accuracy: 0.5100
# Epoch 454, Train Loss: 0.5843, Val Loss: 1.9996, F1 Micro: 0.5400, F1 Macro: 0.5400, Accuracy: 0.5400
# Epoch 455, Train Loss: 0.5790, Val Loss: 2.0362, F1 Micro: 0.5300, F1 Macro: 0.5398, Accuracy: 0.5300
# Epoch 456, Train Loss: 0.5614, Val Loss: 1.9970, F1 Micro: 0.5167, F1 Macro: 0.5206, Accuracy: 0.5167
# Epoch 457, Train Loss: 0.5406, Val Loss: 1.9876, F1 Micro: 0.5400, F1 Macro: 0.5448, Accuracy: 0.5400
# Epoch 458, Train Loss: 0.5209, Val Loss: 1.9961, F1 Micro: 0.5467, F1 Macro: 0.5520, Accuracy: 0.5467
# Epoch 459, Train Loss: 0.5232, Val Loss: 2.0544, F1 Micro: 0.5433, F1 Macro: 0.5389, Accuracy: 0.5433
# Epoch 460, Train Loss: 0.5571, Val Loss: 2.0117, F1 Micro: 0.5300, F1 Macro: 0.5298, Accuracy: 0.5300
# Epoch 461, Train Loss: 0.5653, Val Loss: 2.0160, F1 Micro: 0.5367, F1 Macro: 0.5404, Accuracy: 0.5367
# Epoch 462, Train Loss: 0.5982, Val Loss: 2.0912, F1 Micro: 0.5333, F1 Macro: 0.5409, Accuracy: 0.5333
# Epoch 463, Train Loss: 0.5451, Val Loss: 2.0664, F1 Micro: 0.5200, F1 Macro: 0.5184, Accuracy: 0.5200
# Epoch 464, Train Loss: 0.5444, Val Loss: 2.0214, F1 Micro: 0.5533, F1 Macro: 0.5429, Accuracy: 0.5533
# Epoch 465, Train Loss: 0.5561, Val Loss: 2.0115, F1 Micro: 0.5400, F1 Macro: 0.5445, Accuracy: 0.5400
# Epoch 466, Train Loss: 0.5249, Val Loss: 2.0496, F1 Micro: 0.5300, F1 Macro: 0.5421, Accuracy: 0.5300
# Epoch 467, Train Loss: 0.5422, Val Loss: 2.0646, F1 Micro: 0.5300, F1 Macro: 0.5322, Accuracy: 0.5300
# Epoch 468, Train Loss: 0.5408, Val Loss: 1.9931, F1 Micro: 0.5500, F1 Macro: 0.5507, Accuracy: 0.5500
# Epoch 469, Train Loss: 0.5390, Val Loss: 2.0421, F1 Micro: 0.5533, F1 Macro: 0.5509, Accuracy: 0.5533
# Epoch 470, Train Loss: 0.5573, Val Loss: 2.0127, F1 Micro: 0.5567, F1 Macro: 0.5567, Accuracy: 0.5567
# Epoch 471, Train Loss: 0.5246, Val Loss: 2.0497, F1 Micro: 0.5433, F1 Macro: 0.5460, Accuracy: 0.5433
# Epoch 472, Train Loss: 0.5334, Val Loss: 2.0566, F1 Micro: 0.5400, F1 Macro: 0.5429, Accuracy: 0.5400
# Epoch 473, Train Loss: 0.5579, Val Loss: 2.0556, F1 Micro: 0.5267, F1 Macro: 0.5223, Accuracy: 0.5267
# Epoch 474, Train Loss: 0.5393, Val Loss: 2.0725, F1 Micro: 0.5367, F1 Macro: 0.5237, Accuracy: 0.5367
# Epoch 475, Train Loss: 0.5197, Val Loss: 2.0753, F1 Micro: 0.5200, F1 Macro: 0.5113, Accuracy: 0.5200
# Epoch 476, Train Loss: 0.5462, Val Loss: 2.0825, F1 Micro: 0.5367, F1 Macro: 0.5406, Accuracy: 0.5367
# Epoch 477, Train Loss: 0.5420, Val Loss: 2.0797, F1 Micro: 0.5300, F1 Macro: 0.5322, Accuracy: 0.5300
# Epoch 478, Train Loss: 0.5345, Val Loss: 2.0247, F1 Micro: 0.5567, F1 Macro: 0.5611, Accuracy: 0.5567
# Epoch 479, Train Loss: 0.5129, Val Loss: 2.0948, F1 Micro: 0.5233, F1 Macro: 0.5244, Accuracy: 0.5233
# Epoch 480, Train Loss: 0.5126, Val Loss: 2.0633, F1 Micro: 0.5400, F1 Macro: 0.5436, Accuracy: 0.5400
# Epoch 481, Train Loss: 0.5263, Val Loss: 2.0953, F1 Micro: 0.5300, F1 Macro: 0.5346, Accuracy: 0.5300
# Epoch 482, Train Loss: 0.4955, Val Loss: 2.0858, F1 Micro: 0.5333, F1 Macro: 0.5364, Accuracy: 0.5333
# Epoch 483, Train Loss: 0.5057, Val Loss: 2.1010, F1 Micro: 0.5400, F1 Macro: 0.5442, Accuracy: 0.5400
# Epoch 484, Train Loss: 0.5383, Val Loss: 2.1049, F1 Micro: 0.5367, F1 Macro: 0.5369, Accuracy: 0.5367
# Epoch 485, Train Loss: 0.5142, Val Loss: 2.1221, F1 Micro: 0.5300, F1 Macro: 0.5363, Accuracy: 0.5300
# Epoch 486, Train Loss: 0.5009, Val Loss: 2.0883, F1 Micro: 0.5400, F1 Macro: 0.5375, Accuracy: 0.5400
# Epoch 487, Train Loss: 0.5172, Val Loss: 2.0729, F1 Micro: 0.5533, F1 Macro: 0.5571, Accuracy: 0.5533
# Epoch 488, Train Loss: 0.5211, Val Loss: 2.1008, F1 Micro: 0.5433, F1 Macro: 0.5409, Accuracy: 0.5433
# Epoch 489, Train Loss: 0.4948, Val Loss: 2.0973, F1 Micro: 0.5533, F1 Macro: 0.5514, Accuracy: 0.5533
# Epoch 490, Train Loss: 0.5272, Val Loss: 2.1672, F1 Micro: 0.5167, F1 Macro: 0.5056, Accuracy: 0.5167
# Epoch 491, Train Loss: 0.5577, Val Loss: 2.1346, F1 Micro: 0.5333, F1 Macro: 0.5294, Accuracy: 0.5333
# Epoch 492, Train Loss: 0.5140, Val Loss: 2.1025, F1 Micro: 0.5533, F1 Macro: 0.5500, Accuracy: 0.5533
# Epoch 493, Train Loss: 0.4877, Val Loss: 2.0881, F1 Micro: 0.5567, F1 Macro: 0.5641, Accuracy: 0.5567
# Epoch 494, Train Loss: 0.5121, Val Loss: 2.1267, F1 Micro: 0.5467, F1 Macro: 0.5572, Accuracy: 0.5467
# Epoch 495, Train Loss: 0.5115, Val Loss: 2.0842, F1 Micro: 0.5600, F1 Macro: 0.5657, Accuracy: 0.5600
# Epoch 496, Train Loss: 0.4950, Val Loss: 2.1244, F1 Micro: 0.5433, F1 Macro: 0.5422, Accuracy: 0.5433
# Epoch 497, Train Loss: 0.4960, Val Loss: 2.1332, F1 Micro: 0.5333, F1 Macro: 0.5299, Accuracy: 0.5333
# Epoch 498, Train Loss: 0.5254, Val Loss: 2.1236, F1 Micro: 0.5533, F1 Macro: 0.5539, Accuracy: 0.5533
# Epoch 499, Train Loss: 0.5141, Val Loss: 2.1307, F1 Micro: 0.5300, F1 Macro: 0.5268, Accuracy: 0.5300
# Epoch 500, Train Loss: 0.5020, Val Loss: 2.2021, F1 Micro: 0.5033, F1 Macro: 0.5036, Accuracy: 0.5033
# Test set evaluation - F1 Micro: 0.5033, F1 Macro: 0.5036, Accuracy: 0.5033

# %%
print(np.mean(f1_micro_test_list))
print(np.mean(f1_macro_test_list))
print(np.mean(accuracy_test_list))
# Out:
# 0.5016666666666667
# 0.5022956600878323
# 0.5016666666666667
